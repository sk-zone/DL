# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt

#Load and preprocess CIFAR-10 data
(train_images, _), (_, _) = tf.keras.datasets.cifar10.load_data()
train_images = (train_images.astype('float32') - 127.5) / 127.5  #Normalize to [-1, 1]

BUFFER_SIZE = 50000
BATCH_SIZE = 128
EPOCHS = 100  #More epochs
NOISE_DIM = 100

train_dataset = tf.data.Dataset.from_tensor_slices(train_images).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

#Modified Generator
def make_generator_model():
    model = models.Sequential()
    model.add(layers.Dense(4 * 4 * 512, use_bias=False, input_shape=(NOISE_DIM,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())
    model.add(layers.Reshape((4, 4, 512)))

    model.add(layers.Conv2DTranspose(256, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(128, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(3, (5, 5), strides=(1, 1), padding='same', activation='tanh'))

    return model

#Discriminator
def make_discriminator_model():
    model = models.Sequential()
    model.add(layers.Conv2D(64, (3, 3), strides=(2, 2), padding='same', input_shape=[32, 32, 3]))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(128, (3, 3), strides=(2, 2), padding='same'))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())
    model.add(layers.Dense(1))

    return model


#Loss functions and optimizers
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

generator = make_generator_model()
discriminator = make_discriminator_model()

generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)


#Training function
@tf.function
def train_step(images):
    noise = tf.random.normal([BATCH_SIZE, NOISE_DIM])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator(noise, training=True)

        real_output = discriminator(images, training=True)
        fake_output = discriminator(generated_images, training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss


#Training loop
def train(dataset, epochs):
    for epoch in range(epochs):
        gen_loss_total = 0
        disc_loss_total = 0
        num_batches = 0

        for image_batch in dataset:
            gen_loss, disc_loss = train_step(image_batch)
            gen_loss_total += gen_loss
            disc_loss_total += disc_loss
            num_batches += 1

        print(f'Epoch {epoch+1}, Generator Loss: {gen_loss_total/num_batches:.4f}, Discriminator Loss: {disc_loss_total/num_batches:.4f}')

        if (epoch + 1) % 10 == 0:
            generate_and_plot_images(generator)

#Generate and plot images
def generate_and_plot_images(model, num_images=16):
    noise = tf.random.normal([num_images, NOISE_DIM])
    generated_images = model(noise, training=False)

    plt.figure(figsize=(4, 4))
    for i in range(num_images):
        plt.subplot(4, 4, i + 1)
        plt.imshow((generated_images[i] + 1) / 2)  #Rescale to [0, 1]
        plt.axis('off')
    plt.tight_layout()
    plt.show()


#Training
train(train_dataset, EPOCHS)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1, Generator Loss: 0.9413, Discriminator Loss: 1.3280
# Epoch 2, Generator Loss: 0.5843, Discriminator Loss: 1.4794
# Epoch 3, Generator Loss: 0.7160, Discriminator Loss: 1.3611
# Epoch 4, Generator Loss: 0.7211, Discriminator Loss: 1.3853
# Epoch 5, Generator Loss: 0.6994, Discriminator Loss: 1.3888
# Epoch 6, Generator Loss: 0.8413, Discriminator Loss: 1.3033
# Epoch 7, Generator Loss: 0.8026, Discriminator Loss: 1.3174
# Epoch 8, Generator Loss: 0.7650, Discriminator Loss: 1.3319
# Epoch 9, Generator Loss: 0.7949, Discriminator Loss: 1.3453
# Epoch 10, Generator Loss: 0.7504, Discriminator Loss: 1.3637
# Epoch 11, Generator Loss: 0.7547, Discriminator Loss: 1.3877
# Epoch 12, Generator Loss: 0.8276, Discriminator Loss: 1.3242
# Epoch 13, Generator Loss: 0.7429, Discriminator Loss: 1.3769
# Epoch 14, Generator Loss: 0.7827, Discriminator Loss: 1.3693
# Epoch 15, Generator Loss: 0.7050, Discriminator Loss: 1.4115
# Epoch 16, Generator Loss: 0.7503, Discriminator Loss: 1.3629
# Epoch 17, Generator Loss: 0.7722, Discriminator Loss: 1.3736
# Epoch 18, Generator Loss: 0.7390, Discriminator Loss: 1.3827
# Epoch 19, Generator Loss: 0.7724, Discriminator Loss: 1.3612
# Epoch 20, Generator Loss: 0.8240, Discriminator Loss: 1.2980
# Epoch 21, Generator Loss: 0.8097, Discriminator Loss: 1.3591
# Epoch 22, Generator Loss: 0.8831, Discriminator Loss: 1.2828
# Epoch 23, Generator Loss: 0.8871, Discriminator Loss: 1.3173
# Epoch 24, Generator Loss: 0.8631, Discriminator Loss: 1.2334
# Epoch 25, Generator Loss: 0.8326, Discriminator Loss: 1.3414
# Epoch 26, Generator Loss: 0.7503, Discriminator Loss: 1.4218
# Epoch 27, Generator Loss: 0.7544, Discriminator Loss: 1.3543
# Epoch 28, Generator Loss: 0.7821, Discriminator Loss: 1.3388
# Epoch 29, Generator Loss: 0.8267, Discriminator Loss: 1.3223
# Epoch 30, Generator Loss: 0.8501, Discriminator Loss: 1.2931
# Epoch 31, Generator Loss: 0.8375, Discriminator Loss: 1.2930
# Epoch 32, Generator Loss: 0.8682, Discriminator Loss: 1.2928
# Epoch 33, Generator Loss: 0.8333, Discriminator Loss: 1.2898
# Epoch 34, Generator Loss: 0.8437, Discriminator Loss: 1.3069
# Epoch 35, Generator Loss: 0.8365, Discriminator Loss: 1.3135
# Epoch 36, Generator Loss: 0.8185, Discriminator Loss: 1.3108
# Epoch 37, Generator Loss: 0.8184, Discriminator Loss: 1.3317
# Epoch 38, Generator Loss: 0.8361, Discriminator Loss: 1.3036
# Epoch 39, Generator Loss: 0.9093, Discriminator Loss: 1.3193
# Epoch 40, Generator Loss: 0.8763, Discriminator Loss: 1.3050
# Epoch 41, Generator Loss: 0.9053, Discriminator Loss: 1.2615
# Epoch 42, Generator Loss: 0.8418, Discriminator Loss: 1.3432
# Epoch 43, Generator Loss: 0.9471, Discriminator Loss: 1.2061
# Epoch 44, Generator Loss: 0.8539, Discriminator Loss: 1.3727
# Epoch 45, Generator Loss: 0.9171, Discriminator Loss: 1.2098
# Epoch 46, Generator Loss: 0.8522, Discriminator Loss: 1.2952
# Epoch 47, Generator Loss: 0.8297, Discriminator Loss: 1.3000
# Epoch 48, Generator Loss: 1.0217, Discriminator Loss: 1.1590
# Epoch 49, Generator Loss: 0.8557, Discriminator Loss: 1.3088
# Epoch 50, Generator Loss: 0.9201, Discriminator Loss: 1.3135
# Epoch 51, Generator Loss: 0.8682, Discriminator Loss: 1.3079
# Epoch 52, Generator Loss: 0.8752, Discriminator Loss: 1.2587
# Epoch 53, Generator Loss: 0.9074, Discriminator Loss: 1.3062
# Epoch 54, Generator Loss: 0.9256, Discriminator Loss: 1.2181
# Epoch 55, Generator Loss: 0.8323, Discriminator Loss: 1.3732
# Epoch 56, Generator Loss: 0.9405, Discriminator Loss: 1.2115
# Epoch 57, Generator Loss: 0.8708, Discriminator Loss: 1.3598
# Epoch 58, Generator Loss: 0.8967, Discriminator Loss: 1.2092
# Epoch 59, Generator Loss: 0.8874, Discriminator Loss: 1.3181
# Epoch 60, Generator Loss: 0.9070, Discriminator Loss: 1.2016
# Epoch 61, Generator Loss: 0.8895, Discriminator Loss: 1.3728
# Epoch 62, Generator Loss: 0.8743, Discriminator Loss: 1.2801
# Epoch 63, Generator Loss: 0.8910, Discriminator Loss: 1.3053
# Epoch 64, Generator Loss: 0.8523, Discriminator Loss: 1.3198
# Epoch 65, Generator Loss: 0.9664, Discriminator Loss: 1.1993
# Epoch 66, Generator Loss: 0.8936, Discriminator Loss: 1.3299
# Epoch 67, Generator Loss: 0.8797, Discriminator Loss: 1.2753
# Epoch 68, Generator Loss: 0.8425, Discriminator Loss: 1.3637
# Epoch 69, Generator Loss: 0.8583, Discriminator Loss: 1.3202
# Epoch 70, Generator Loss: 0.9189, Discriminator Loss: 1.2807
# Epoch 71, Generator Loss: 0.8763, Discriminator Loss: 1.3392
# Epoch 72, Generator Loss: 0.8533, Discriminator Loss: 1.3193
# Epoch 73, Generator Loss: 0.9450, Discriminator Loss: 1.2369
# Epoch 74, Generator Loss: 0.9009, Discriminator Loss: 1.2332
# Epoch 75, Generator Loss: 0.8144, Discriminator Loss: 1.4029
# Epoch 76, Generator Loss: 0.8763, Discriminator Loss: 1.3365
# Epoch 77, Generator Loss: 0.9121, Discriminator Loss: 1.2242
# Epoch 78, Generator Loss: 0.9259, Discriminator Loss: 1.2697
# Epoch 79, Generator Loss: 1.0075, Discriminator Loss: 1.3123
# Epoch 80, Generator Loss: 0.9049, Discriminator Loss: 1.2478
# Epoch 81, Generator Loss: 0.8887, Discriminator Loss: 1.2685
# Epoch 82, Generator Loss: 0.8973, Discriminator Loss: 1.3128
# Epoch 83, Generator Loss: 0.9637, Discriminator Loss: 1.2246
# Epoch 84, Generator Loss: 0.9471, Discriminator Loss: 1.2618
# Epoch 85, Generator Loss: 0.9550, Discriminator Loss: 1.2686
# Epoch 86, Generator Loss: 0.9324, Discriminator Loss: 1.2582
# Epoch 87, Generator Loss: 1.0081, Discriminator Loss: 1.1514
# Epoch 88, Generator Loss: 1.0179, Discriminator Loss: 1.1948
# Epoch 89, Generator Loss: 0.9267, Discriminator Loss: 1.2701
# Epoch 90, Generator Loss: 0.9441, Discriminator Loss: 1.2799
# Epoch 91, Generator Loss: 0.9989, Discriminator Loss: 1.2354
# Epoch 92, Generator Loss: 1.0092, Discriminator Loss: 1.2566
# Epoch 93, Generator Loss: 1.0824, Discriminator Loss: 1.1406
# Epoch 94, Generator Loss: 1.0824, Discriminator Loss: 1.1564
# Epoch 95, Generator Loss: 1.1156, Discriminator Loss: 1.1441
# Epoch 96, Generator Loss: 1.0565, Discriminator Loss: 1.2693
# Epoch 97, Generator Loss: 1.0819, Discriminator Loss: 1.1652
# Epoch 98, Generator Loss: 1.0858, Discriminator Loss: 1.1737
# Epoch 99, Generator Loss: 1.0171, Discriminator Loss: 1.2099
# Epoch 100, Generator Loss: 1.0359, Discriminator Loss: 1.2465
